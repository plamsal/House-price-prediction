# %% [markdown]
# # importing numpy, .....

# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# #

# %%
x = [1,2,3]
y = [4,5,6]
z = [5,6,9]

plt.plot(x, y)
plt.plot(x, z)
plt.title("test plot")
plt.xlabel("x")

plt.ylabel("y and z")
plt.legend("this is x","this is x")
plt.show()

# %%
sample_data = pd.read_csv('kc_house_data.csv')

# %%
sample_data
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.shape
# Out:
# (21613, 21)

# %%
sample_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
sample_data.price
# Out:
# 0         221900.0
# 1         538000.0
# 2         180000.0
# 3         604000.0
# 4         510000.0
# 5        1225000.0
# 6         257500.0
# 7         291850.0
# 8         229500.0
# 9         323000.0
# 10        662500.0
# 11        468000.0
# 12        310000.0
# 13        400000.0
# 14        530000.0
# 15        650000.0
# 16        395000.0
# 17        485000.0
# 18        189000.0
# 19        230000.0
# 20        385000.0
# 21       2000000.0
# 22        285000.0
# 23        252700.0
# 24        329000.0
# 25        233000.0
# 26        937000.0
# 27        667000.0
# 28        438000.0
# 29        719000.0
#            ...
# 21583     399950.0
# 21584     380000.0
# 21585     270000.0
# 21586     505000.0
# 21587     385000.0
# 21588     414500.0
# 21589     347500.0
# 21590    1222500.0
# 21591     572000.0
# 21592     475000.0
# 21593    1088000.0
# 21594     350000.0
# 21595     520000.0
# 21596     679950.0
# 21597    1575000.0
# 21598     541800.0
# ...

# %%
plt.plot(sample_data.price, sample_data.bedrooms,'o')
plt.show()

# %%
sum(sample_data.price)
# Out:
# 11672925008.0

# %%
no_house = len(sample_data.price)

print(no_house)
# Out:
# 21613

# %%
 tuple(sample_data["price"])
# Out:
# (221900.0,
#  538000.0,
#  180000.0,
#  604000.0,
#  510000.0,
#  1225000.0,
#  257500.0,
#  291850.0,
#  229500.0,
#  323000.0,
#  662500.0,
#  468000.0,
#  310000.0,
#  400000.0,
#  530000.0,
#  650000.0,
#  395000.0,
#  485000.0,
#  189000.0,
#  230000.0,
#  385000.0,
#  2000000.0,
#  285000.0,
#  252700.0,
#  329000.0,
#  233000.0,
#  937000.0,
#  667000.0,
#  438000.0,
#  719000.0,
#  580500.0,
#  280000.0,
#  687500.0,
#  535000.0,
#  322500.0,
#  696000.0,
#  550000.0,
#  640000.0,
#  240000.0,
#  605000.0,
#  625000.0,
#  775000.0,
#  861990.0,
#  685000.0,
#  309000.0,
#  488000.0,
#  210490.0,
#  785000.0,
#  450000.0,
#  1350000.0,
#  228000.0,
#  345000.0,
#  600000.0,
#  585000.0,
#  920000.0,
#  885000.0,
#  292500.0,
#  301000.0,
#  951000.0,
#  430000.0,
#  650000.0,
#  289000.0,
#  505000.0,
#  549000.0,
#  425000.0,
#  317625.0,
#  975000.0,
#  287000.0,
#  204000.0,
#  1325000.0,
#  1040000.0,
#  325000.0,
#  571000.0,
#  360000.0,
#  349000.0,
#  832500.0,
# ...
